# %%
from natsort import natsorted
import cv2

import numpy as np
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *
from natsort import natsorted
#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 4 Physical GPUs, 4 Logical GPUs

# %%
frame_folders = ['pass5-10/all_frames','pass11-15/all_frames','pass16-20/all_frames','pass21-25/all_frames','pass26-30/all_frames','pass31-35/all_frames','pass36-41/all_frames']
mask_folders = ['pass5-10/all_masks','pass11-15/all_masks','pass16-20/all_masks','pass21-25/all_masks','pass26-30/all_masks','pass31-35/all_masks','pass36-41/all_masks']
zbuff_folders = ['pass5-10/all_zbuffs','pass11-15/all_zbuffs','pass16-20/all_zbuffs','pass21-25/all_zbuffs','pass26-30/all_zbuffs','pass31-35/all_zbuffs','pass36-41/all_zbuffs']
folders = [frame_folders,mask_folders,zbuff_folders]
all_frames = []
all_masks = []
all_zbuffs = []

# %%
for folder in folders:
  #print(folder)
  if folder is frame_folders:
    #print(folder)
    for folder2 in natsorted(folder):
      #print(folder2)
      for frame in natsorted(os.listdir(folder2)):
        frame_pic = os.path.join(folder2,frame)
        #print(frame_pic)
        all_frames.append(frame_pic)

  if folder is mask_folders:
        #print(folder)
    for folder2 in natsorted(folder):
      #print(folder2)
      for mask in natsorted(os.listdir(folder2)):
        mask_pic = os.path.join(folder2,mask)
        #print(mask)
        all_masks.append(mask_pic)

  if folder is zbuff_folders:
    for folder2 in natsorted(folder):
     # print(folder2)
      for zbuff in natsorted(os.listdir(folder2)):
        zbuff_pic = os.path.join(folder2,zbuff)
        #print(zbuff)
        all_zbuffs.append(zbuff_pic)

# %%
all_frames = natsorted(all_frames)
all_masks = natsorted(all_masks)
all_zbuffs = natsorted(all_zbuffs)

# %%
l_frame_paths = []
for i in range(0,len(all_frames),2):
      l_frame_paths.append(all_frames[i])
print('l_frames: ', l_frame_paths)

r_frame_paths = []
for i in range(1,len(all_frames),2):
      r_frame_paths.append(all_frames[i])
print('r_frames: ',r_frame_paths)

l_mask_paths = []
for i in range(0,len(all_frames),2):
      l_mask_paths.append(all_masks[i])
print('l_masks: ', l_mask_paths)

r_mask_paths = []
for i in range(1,len(all_frames),2):
      r_mask_paths.append(all_masks[i])
print('r_masks: ', r_mask_paths)

l_zbuff_paths = []
for i in range(0,len(all_zbuffs),2):
      l_zbuff_paths.append(all_zbuffs[i])
print('l_zbuffs: ', l_zbuff_paths)

r_zbuff_paths = []
for i in range(1,len(all_zbuffs),2):
      r_zbuff_paths.append(all_zbuffs[i])
print('r_zbuffs: ', r_zbuff_paths)
# Out:
# l_frames:  ['pass5-10/all_frames/Frame1.png', 'pass5-10/all_frames/Frame3.png', 'pass5-10/all_frames/Frame5.png', 'pass5-10/all_frames/Frame7.png', 'pass5-10/all_frames/Frame9.png', 'pass5-10/all_frames/Frame11.png', 'pass5-10/all_frames/Frame13.png', 'pass5-10/all_frames/Frame15.png', 'pass5-10/all_frames/Frame17.png', 'pass5-10/all_frames/Frame19.png', 'pass5-10/all_frames/Frame21.png', 'pass5-10/all_frames/Frame23.png', 'pass5-10/all_frames/Frame25.png', 'pass5-10/all_frames/Frame27.png', 'pass5-10/all_frames/Frame29.png', 'pass5-10/all_frames/Frame31.png', 'pass5-10/all_frames/Frame33.png', 'pass5-10/all_frames/Frame35.png', 'pass5-10/all_frames/Frame37.png', 'pass5-10/all_frames/Frame39.png', 'pass5-10/all_frames/Frame41.png', 'pass5-10/all_frames/Frame43.png', 'pass5-10/all_frames/Frame45.png', 'pass5-10/all_frames/Frame47.png', 'pass5-10/all_frames/Frame49.png', 'pass5-10/all_frames/Frame51.png', 'pass5-10/all_frames/Frame53.png', 'pass5-10/all_frames/Frame55.png', 'pass5-10/all_frames/Frame57.png', 'pass5-10/all_frames/Frame59.png', 'pass5-10/all_frames/Frame61.png', 'pass5-10/all_frames/Frame63.png', 'pass5-10/all_frames/Frame65.png', 'pass5-10/all_frames/Frame67.png', 'pass5-10/all_frames/Frame69.png', 'pass5-10/all_frames/Frame71.png', 'pass5-10/all_frames/Frame73.png', 'pass5-10/all_frames/Frame75.png', 'pass5-10/all_frames/Frame77.png', 'pass5-10/all_frames/Frame79.png', 'pass5-10/all_frames/Frame81.png', 'pass5-10/all_frames/Frame83.png', 'pass5-10/all_frames/Frame85.png', 'pass5-10/all_frames/Frame87.png', 'pass5-10/all_frames/Frame89.png', 'pass5-10/all_frames/Frame91.png', 'pass5-10/all_frames/Frame93.png', 'pass5-10/all_frames/Frame95.png', 'pass5-10/all_frames/Frame97.png', 'pass5-10/all_frames/Frame99.png', 'pass5-10/all_frames/Frame101.png', 'pass5-10/all_frames/Frame103.png', 'pass5-10/all_frames/Frame105.png', 'pass5-10/all_frames/Frame107.png', 'pass5-10/all_frames/Frame109.png', 'pass5-10/all_frames/Frame111.png', 'pass5-10/all_frames/Frame113.png', 'pass5-10/all_frames/Frame115.png', 'pass5-10/all_frames/Frame117.png', 'pass5-10/all_frames/Frame119.png', 'pass5-10/all_frames/Frame121.png', 'pass5-10/all_frames/Frame123.png', 'pass5-10/all_frames/Frame125.png', 'pass5-10/all_frames/Frame127.png', 'pass5-10/all_frames/Frame129.png', 'pass5-10/all_frames/Frame131.png', 'pass5-10/all_frames/Frame133.png', 'pass5-10/all_frames/Frame135.png', 'pass5-10/all_frames/Frame137.png', 'pass5-10/all_frames/Frame139.png', 'pass5-10/all_frames/Frame141.png', 'pass5-10/all_frames/Frame143.png', 'pass5-10/all_frames/Frame145.png', 'pass5-10/all_frames/Frame147.png', 'pass5-10/all_frames/Frame149.png', 'pass5-10/all_frames/Frame151.png', 'pass5-10/all_frames/Frame153.png', 'pass5-10/all_frames/Frame155.png', 'pass5-10/all_frames/Frame157.png', 'pass5-10/all_frames/Frame159.png', 'pass5-10/all_frames/Frame161.png', 'pass5-10/all_frames/Frame163.png', 'pass5-10/all_frames/Frame165.png', 'pass5-10/all_frames/Frame167.png', 'pass5-10/all_frames/Frame169.png', 'pass5-10/all_frames/Frame171.png', 'pass5-10/all_frames/Frame173.png', 'pass5-10/all_frames/Frame175.png', 'pass5-10/all_frames/Frame177.png', 'pass5-10/all_frames/Frame179.png', 'pass5-10/all_frames/Frame181.png', 'pass5-10/all_frames/Frame183.png', 'pass5-10/all_frames/Frame185.png', 'pass5-10/all_frames/Frame187.png', 'pass5-10/all_frames/Frame189.png', 'pass5-10/all_frames/Frame191.png', 'pass5-10/all_frames/Frame193.png', 'pass5-10/all_frames/Frame195.png', 'pass5-10/all_frames/Frame197.png', 'pass5-10/all_frames/Frame199.png', 'pass5-10/all_frames/Frame201.png', 'pass5-10/all_frames/Frame203.png', 'pass5-10/all_frames/Frame205.png', 'pass5-10/all_frames/Frame207.png', 'pass5-10/all_frames/Frame209.png', 'pass5-10/all_frames/Frame211.png', 'pass5-10/all_frames/Frame213.png', 'pass5-10/all_frames/Frame215.png', 'pass5-10/all_frames/Frame217.png', 'pass5-10/all_frames/Frame219.png', 'pass5-10/all_frames/Frame221.png', 'pass5-10/all_frames/Frame223.png', 'pass5-10/a ...
# r_frames:  ['pass5-10/all_frames/Frame2.png', 'pass5-10/all_frames/Frame4.png', 'pass5-10/all_frames/Frame6.png', 'pass5-10/all_frames/Frame8.png', 'pass5-10/all_frames/Frame10.png', 'pass5-10/all_frames/Frame12.png', 'pass5-10/all_frames/Frame14.png', 'pass5-10/all_frames/Frame16.png', 'pass5-10/all_frames/Frame18.png', 'pass5-10/all_frames/Frame20.png', 'pass5-10/all_frames/Frame22.png', 'pass5-10/all_frames/Frame24.png', 'pass5-10/all_frames/Frame26.png', 'pass5-10/all_frames/Frame28.png', 'pass5-10/all_frames/Frame30.png', 'pass5-10/all_frames/Frame32.png', 'pass5-10/all_frames/Frame34.png', 'pass5-10/all_frames/Frame36.png', 'pass5-10/all_frames/Frame38.png', 'pass5-10/all_frames/Frame40.png', 'pass5-10/all_frames/Frame42.png', 'pass5-10/all_frames/Frame44.png', 'pass5-10/all_frames/Frame46.png', 'pass5-10/all_frames/Frame48.png', 'pass5-10/all_frames/Frame50.png', 'pass5-10/all_frames/Frame52.png', 'pass5-10/all_frames/Frame54.png', 'pass5-10/all_frames/Frame56.png', 'pass5-10/all_frames/Frame58.png', 'pass5-10/all_frames/Frame60.png', 'pass5-10/all_frames/Frame62.png', 'pass5-10/all_frames/Frame64.png', 'pass5-10/all_frames/Frame66.png', 'pass5-10/all_frames/Frame68.png', 'pass5-10/all_frames/Frame70.png', 'pass5-10/all_frames/Frame72.png', 'pass5-10/all_frames/Frame74.png', 'pass5-10/all_frames/Frame76.png', 'pass5-10/all_frames/Frame78.png', 'pass5-10/all_frames/Frame80.png', 'pass5-10/all_frames/Frame82.png', 'pass5-10/all_frames/Frame84.png', 'pass5-10/all_frames/Frame86.png', 'pass5-10/all_frames/Frame88.png', 'pass5-10/all_frames/Frame90.png', 'pass5-10/all_frames/Frame92.png', 'pass5-10/all_frames/Frame94.png', 'pass5-10/all_frames/Frame96.png', 'pass5-10/all_frames/Frame98.png', 'pass5-10/all_frames/Frame100.png', 'pass5-10/all_frames/Frame102.png', 'pass5-10/all_frames/Frame104.png', 'pass5-10/all_frames/Frame106.png', 'pass5-10/all_frames/Frame108.png', 'pass5-10/all_frames/Frame110.png', 'pass5-10/all_frames/Frame112.png', 'pass5-10/all_frames/Frame114.png', 'pass5-10/all_frames/Frame116.png', 'pass5-10/all_frames/Frame118.png', 'pass5-10/all_frames/Frame120.png', 'pass5-10/all_frames/Frame122.png', 'pass5-10/all_frames/Frame124.png', 'pass5-10/all_frames/Frame126.png', 'pass5-10/all_frames/Frame128.png', 'pass5-10/all_frames/Frame130.png', 'pass5-10/all_frames/Frame132.png', 'pass5-10/all_frames/Frame134.png', 'pass5-10/all_frames/Frame136.png', 'pass5-10/all_frames/Frame138.png', 'pass5-10/all_frames/Frame140.png', 'pass5-10/all_frames/Frame142.png', 'pass5-10/all_frames/Frame144.png', 'pass5-10/all_frames/Frame146.png', 'pass5-10/all_frames/Frame148.png', 'pass5-10/all_frames/Frame150.png', 'pass5-10/all_frames/Frame152.png', 'pass5-10/all_frames/Frame154.png', 'pass5-10/all_frames/Frame156.png', 'pass5-10/all_frames/Frame158.png', 'pass5-10/all_frames/Frame160.png', 'pass5-10/all_frames/Frame162.png', 'pass5-10/all_frames/Frame164.png', 'pass5-10/all_frames/Frame166.png', 'pass5-10/all_frames/Frame168.png', 'pass5-10/all_frames/Frame170.png', 'pass5-10/all_frames/Frame172.png', 'pass5-10/all_frames/Frame174.png', 'pass5-10/all_frames/Frame176.png', 'pass5-10/all_frames/Frame178.png', 'pass5-10/all_frames/Frame180.png', 'pass5-10/all_frames/Frame182.png', 'pass5-10/all_frames/Frame184.png', 'pass5-10/all_frames/Frame186.png', 'pass5-10/all_frames/Frame188.png', 'pass5-10/all_frames/Frame190.png', 'pass5-10/all_frames/Frame192.png', 'pass5-10/all_frames/Frame194.png', 'pass5-10/all_frames/Frame196.png', 'pass5-10/all_frames/Frame198.png', 'pass5-10/all_frames/Frame200.png', 'pass5-10/all_frames/Frame202.png', 'pass5-10/all_frames/Frame204.png', 'pass5-10/all_frames/Frame206.png', 'pass5-10/all_frames/Frame208.png', 'pass5-10/all_frames/Frame210.png', 'pass5-10/all_frames/Frame212.png', 'pass5-10/all_frames/Frame214.png', 'pass5-10/all_frames/Frame216.png', 'pass5-10/all_frames/Frame218.png', 'pass5-10/all_frames/Frame220.png', 'pass5-10/all_frames/Frame222.png', 'pass5-10/all_frames/Frame224.png', 'pass5-10 ...
# l_masks:  ['pass5-10/all_masks/Mask1.png', 'pass5-10/all_masks/Mask3.png', 'pass5-10/all_masks/Mask5.png', 'pass5-10/all_masks/Mask7.png', 'pass5-10/all_masks/Mask9.png', 'pass5-10/all_masks/Mask11.png', 'pass5-10/all_masks/Mask13.png', 'pass5-10/all_masks/Mask15.png', 'pass5-10/all_masks/Mask17.png', 'pass5-10/all_masks/Mask19.png', 'pass5-10/all_masks/Mask21.png', 'pass5-10/all_masks/Mask23.png', 'pass5-10/all_masks/Mask25.png', 'pass5-10/all_masks/Mask27.png', 'pass5-10/all_masks/Mask29.png', 'pass5-10/all_masks/Mask31.png', 'pass5-10/all_masks/Mask33.png', 'pass5-10/all_masks/Mask35.png', 'pass5-10/all_masks/Mask37.png', 'pass5-10/all_masks/Mask39.png', 'pass5-10/all_masks/Mask41.png', 'p
'pass5-10/all_zbuffs/Zbuff170.png', 'pass5-10/all_zbuffs/Zbuff172.png', 'pass5-10/all_zbuffs/Zbuff174.png', 'pass5-10/all_zbuffs/Zbuff176.png', 'pass5-10/all_zbuffs/Zbuff178.png', 'pass5-10/all_zbuffs/Zbuff180.png', 'pass5-10/all_zbuffs/Zbuff182.png', 'pass5-10/all_zbuffs/Zbuff184.png', 'pass5-10/all_zbuffs/Zbuff186.png', 'pass5-10/all_zbuffs/Zbuff188.png', 'pass5-10/all_zbuffs/Zbuff190.png', 'pass5-10/all_zbuffs/Zbuff192.png', 'pass5-10/all_zbuffs/Zbuff194.png', 'pass5-10/all_zbuffs/Zbuff196.png', 'pass5-10/all_zbuffs/Zbuff198.png', 'pass5-10/all_zbuffs/Zbuff200.png', 'pass5-10/all_zbuffs/Zbuff202.png', 'pass5-10/all_zbuffs/Zbuff204.png', 'pass5-10/all_zbuffs/Zbuff206.png', 'pass5-10/all_zbuffs/Zbuff208.png', 'pass5-10/all_zbuffs/Zbuff210.png', 'pass5-10/all_zbuffs/Zbuff212.png', 'pass5-10/all_zbuffs/Zbuff214.png', 'pass5-10/all_zbuffs/Zbuff216.png', 'pass5-10/all_zbuffs/Zbuff218.png', 'pass5-10/all_zbuffs/Zbuff220.png', 'pass5-10/all_zbuffs/Zbuff222.png', 'pass5-10/all_zbuffs/Zbuff224.png', 'pass5-10 ...

# %%
label_codes = ([(0,0,0), # colour codes for using generator
(0,44,99),
(208,205,206),
(132,203,239),
(110,65,189),
(164,175,230),
(105,30,118),
(179,212,144),
(27,86,73),
(31,125,8),
(2,146,228),
(68,254,231),
(38,121,190),
(105,137,155),
(211,106,112),
(147,41,158),
(18,233,208),
(113,190,7),
(245,129,204),
(135,210,143),
(100,103,113),
(108,144,181),
(109,206,231),
(158,5,80),
(190,58,27)])

# label_codes = ([(0,0,0),        ## These are the colour codes for feeding as numpy arrays
# (99,44,0),
# (206,205,208),
# (239,203,132),
# (189,65,110),
# (230,175,164),
# (118,30,105),
# (144,212,179),
# (73,86,27),
# (8,125,31),
# (228,146,2),
# (231,254,68),
# (190,121,38),
# (155,137,105),
# (112,106,211),
# (158,41,147),
# (208,233,18),
# (7,190,113),
# (204,129,245),
# (143,210,135),
# (113,103,100),
# (181,144,108),
# (231,206,109),
# (80,5,158),
# (27,58,190)])


label_names = (['Background',
'Apple',
'Avocado',
'Muffin',
'Lemon',
'Ginger',
'Garlic',
'Carrot',
'Foodfight',
'Ralphie',
'Corn',
'Courgette',
'Kiwi',
'Parsnip',
'Playmobil',
'Plum',
'Pomegranate'
'Robin',
'Roll',
'Scone',
'Seeded',
'Sprout',
'Thor',
'Tomato',
'Corn2'
])

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    #print(rgb_image.shape)
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    #print(shape)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        #print('i is: ', i)
        #print('cls is: ', cls)
        #encoded_image[:,:,i] = np.where(rgb_image==colormap[i],encoded_image[:,:,i],colormap[cls]).reshape(shape[:2])
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
        #print(rgb_image.shape)
        #encoded_image[:,:,i] = np.argmax(encoded_image[:,:,i])
        #encoded_image[:,:,i] = np.where(encoded_image[:,:,i]== 1,encoded_image[:,:,i],255)
        #encoded_image = 1-encoded_image
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    
    single_layer = np.argmax(onehot, axis=2)
    #print(single_layer)
    output = np.zeros(onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        #print(k)
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %%
frame_train_args = dict()
mask_train_args = dict()
zbuff_train_args = dict()
l_train_gen = ImageDataGenerator(**frame_train_args)
r_train_gen = ImageDataGenerator(**frame_train_args)
zbuff_train_gen = ImageDataGenerator(**zbuff_train_args)
target_train_gen = ImageDataGenerator(**mask_train_args)

# %%
frame_val_args = dict()
mask_val_args = dict()
zbuff_val_args = dict()
l_val_gen = ImageDataGenerator(**frame_val_args)
r_val_gen = ImageDataGenerator(**frame_val_args)
zbuff_val_gen = ImageDataGenerator(**zbuff_val_args)
target_val_gen = ImageDataGenerator(**mask_val_args)

# %%
frame_test_args = dict()
mask_test_args = dict()
zbuff_test_args = dict()
l_test_gen = ImageDataGenerator(**frame_test_args)
r_test_gen = ImageDataGenerator(**frame_test_args)
zbuff_test_gen = ImageDataGenerator(**zbuff_test_args)
target_test_gen = ImageDataGenerator(**mask_test_args)

# %%
batch_size = 8

# %%
def StereoDepthGen(batch_size = batch_size, seed = 5, target_size = (224,224)):  ## Two Inputs, two outputs

      data_path = 'GeneratorData/'
        
      left_gen = l_train_gen.flow_from_directory('GeneratorData/l_train_frames/',batch_size = batch_size,
                                           target_size = target_size, shuffle = False,
                                           seed = 5)
  
      right_gen = r_train_gen.flow_from_directory('GeneratorData/r_train_frames/', batch_size= batch_size,
                                            target_size = target_size, shuffle = False,
                                            seed = 5)
      depth_gen = zbuff_train_gen.flow_from_directory('GeneratorData/l_train_zbuffs/', batch_size = batch_size,
                                                     target_size = target_size, shuffle = False,
                                                     seed = 5)
    
  
      left_mask = target_train_gen.flow_from_directory('GeneratorData/l_train_masks/', batch_size = batch_size,
                                                  target_size = target_size, shuffle = False,
                                                  seed = 5)
  
      right_mask = target_train_gen.flow_from_directory('GeneratorData/r_train_masks/', batch_size = batch_size,
                                                  target_size = target_size, shuffle = False,
                                                  seed = 5)
  
      while True:
        left = left_gen.next()
        right = right_gen.next()
        depth= depth_gen.next()
        left_target = left_mask.next()
        right_target = right_mask.next()
        l_mask = [rgb_to_onehot(left_target[0][x,:,:,:], id2code) for x in range(left_target[0].shape[0])]
        r_mask = [rgb_to_onehot(right_target[0][x,:,:,:], id2code) for x in range(right_target[0].shape[0])]

        yield [left[0],right[0]], [np.asarray(l_mask),np.asarray(r_mask),np.asarray(depth[0])]

# %%
def StereoDepthGenVal(batch_size = batch_size, seed = 5, target_size = (224,224)):  ## Two Inputs, two outputs

      data_path = 'GeneratorData/'
        
      left_gen = l_val_gen.flow_from_directory('GeneratorData/l_val_frames/',batch_size = batch_size,
                                           target_size = target_size, shuffle = False,
                                           seed = 5)
  
      right_gen = r_val_gen.flow_from_directory('GeneratorData/r_val_frames/', batch_size= batch_size,
                                            target_size = target_size, shuffle = False,
                                            seed = 5)
      depth_gen = zbuff_val_gen.flow_from_directory('GeneratorData/l_val_zbuffs/', batch_size = batch_size,
                                                     target_size = target_size, shuffle = False,
                                                     seed = 5)
    
  
      left_mask = target_val_gen.flow_from_directory('GeneratorData/l_val_masks/', batch_size = batch_size,
                                                  target_size = target_size, shuffle = False,
                                                  seed = 5)
  
      right_mask = target_val_gen.flow_from_directory('GeneratorData/r_val_masks/', batch_size = batch_size,
                                                  target_size = target_size, shuffle = False,
                                                  seed = 5)
  
      while True:
        left = left_gen.next()
        right = right_gen.next()
        depth= depth_gen.next()
        left_target = left_mask.next()
        right_target = right_mask.next()
        l_mask = [rgb_to_onehot(left_target[0][x,:,:,:], id2code) for x in range(left_target[0].shape[0])]
        r_mask = [rgb_to_onehot(right_target[0][x,:,:,:], id2code) for x in range(right_target[0].shape[0])]

        yield [left[0],right[0]], [np.asarray(l_mask),np.asarray(r_mask),np.asarray(depth[0])]

# %%
def StereoDepthGenTest(batch_size = 15, seed = 5, target_size = (224,224)):  ## Two Inputs, two outputs

      data_path = 'GeneratorData/'
        
      left_gen = l_test_gen.flow_from_directory('GeneratorData/l_test_frames/',batch_size = batch_size,
                                           target_size = target_size, shuffle = True,
                                           seed = 5)
  
      right_gen = r_test_gen.flow_from_directory('GeneratorData/r_test_frames/', batch_size= batch_size,
                                            target_size = target_size, shuffle = True,
                                            seed = 5)
      depth_gen = zbuff_test_gen.flow_from_directory('GeneratorData/l_test_zbuffs/', batch_size = batch_size,
                                                     target_size = target_size, shuffle = True,
                                                     seed = 5)
    
  
      left_mask = target_test_gen.flow_from_directory('GeneratorData/l_test_masks/', batch_size = batch_size,
                                                  target_size = target_size, shuffle = True,
                                                  seed = 5)
  
      right_mask = target_test_gen.flow_from_directory('GeneratorData/r_test_masks/', batch_size = batch_size,
                                                  target_size = target_size, shuffle = True,
                                                  seed = 5)
  
      while True:
        left = left_gen.next()
        right = right_gen.next()
        depth= depth_gen.next()
        left_target = left_mask.next()
        right_target = right_mask.next()
        l_mask = [rgb_to_onehot(left_target[0][x,:,:,:], id2code) for x in range(left_target[0].shape[0])]
        r_mask = [rgb_to_onehot(right_target[0][x,:,:,:], id2code) for x in range(right_target[0].shape[0])]

        yield [left[0],right[0]], [np.asarray(l_mask),np.asarray(r_mask),np.asarray(depth[0])]

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
def stereoDepthNet():   
    #with strategy.scope():
      n_filters =16
      left_in = Input(shape = (224,224,3),name = 'left_in')
      right_in = Input(shape = (224,224,3),name = 'right_in')
      #depth_in = Input(shape = (224,224,3),name = 'depth_in')

      l_conv1 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(left_in)
      l_conv1 = BatchNormalization()(l_conv1)
      l_conv2 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(l_conv1)
      l_conv2 = BatchNormalization()(l_conv2)
      l_pool1 = MaxPooling2D(pool_size = (2,2),padding = 'same')(l_conv2)

      l_conv3 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(l_pool1)
      l_conv3 = BatchNormalization()(l_conv1)
      l_conv4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(l_conv3)
      l_conv4 = BatchNormalization()(l_conv2)
      l_pool2 = MaxPooling2D(pool_size = (2,2),padding = 'same')(l_conv4)

      l_conv5 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(l_pool2)
      l_conv5 = BatchNormalization()(l_conv5)
      l_conv6 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(l_conv5)
      l_conv6 = BatchNormalization()(l_conv6)
      l_pool3 = MaxPooling2D(pool_size = (2,2),padding = 'same')(l_conv6)

      l_conv7 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(l_pool3)
      l_conv7 = BatchNormalization()(l_conv7)
      l_conv8 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(l_conv7)
      l_conv8 = BatchNormalization()(l_conv8)
      l_pool4 = MaxPooling2D(pool_size = (2,2),padding = 'same')(l_conv8)

      l_conv9 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(l_pool4)
      l_conv9 = BatchNormalization()(l_conv9)
      l_conv10 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(l_conv9)
      l_conv10 = BatchNormalization()(l_conv10)

            
#       d_conv1 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(depth_in)
#       d_conv1 = BatchNormalization()(d_conv1)
#       d_conv2 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(d_conv1)
#       d_conv2 = BatchNormalization()(d_conv2)
#       d_pool1 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv2)

#       d_conv3 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(d_pool1)
#       d_conv3 = BatchNormalization()(d_conv1)
#       d_conv4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(d_conv3)
#       d_conv4 = BatchNormalization()(d_conv2)
#       d_pool2 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv4)

#       d_conv5 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(d_pool2)
#       d_conv5 = BatchNormalization()(d_conv5)
#       d_conv6 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(d_conv5)
#       d_conv6 = BatchNormalization()(d_conv6)
#       d_pool3 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv6)

#       d_conv7 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(d_pool3)
#       d_conv7 = BatchNormalization()(d_conv7)
#       d_conv8 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(d_conv7)
#       d_conv8 = BatchNormalization()(d_conv8)
#       d_pool4 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv8)

#       d_conv9 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(d_pool4)
#       d_conv9 = BatchNormalization()(d_conv9)
#       d_conv10 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(d_conv9)
#       d_conv10 = BatchNormalization()(d_conv10)

      r_conv1 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(right_in)
      r_conv1 = BatchNormalization()(r_conv1)
      r_conv2 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(r_conv1)
      r_conv2 = BatchNormalization()(r_conv2)
      r_pool1 = MaxPooling2D(pool_size = (2,2),padding = 'same')(r_conv2)

      r_conv3 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(r_pool1)
      r_conv3 = BatchNormalization()(r_conv1)
      r_conv4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(r_conv3)
      r_conv4 = BatchNormalization()(r_conv4)
      r_pool2 = MaxPooling2D(pool_size = (2,2),padding = 'same')(r_conv4)

      r_conv5 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(r_pool2)
      r_conv5 = BatchNormalization()(r_conv5)
      r_conv6 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(r_conv5)
      r_conv6 = BatchNormalization()(r_conv6)
      r_pool3 = MaxPooling2D(pool_size = (2,2),padding = 'same')(r_conv6)

      r_conv7 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(r_pool3)
      r_conv7 = BatchNormalization()(r_conv7)
      r_conv8 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(r_conv7)
      r_conv8 = BatchNormalization()(r_conv8)
      r_pool4 = MaxPooling2D(pool_size = (2,2),padding = 'same')(r_conv8)

      r_conv9 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(r_pool4)
      r_conv9 = BatchNormalization()(r_conv9)
      r_conv10 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(r_conv9)
      r_conv10 = BatchNormalization()(r_conv10)


      
      merge = concatenate([l_conv10,r_conv10])

      l_out1 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(merge)
      l_out1 = BatchNormalization()(l_out1)
      l_out1 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(l_out1)
      l_out1 = BatchNormalization()(l_out1)

      l_up1 = concatenate([UpSampling2D(size=(2, 2))(l_out1), l_conv8], axis=3)

      l_out2 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(l_up1)
      l_out2 = BatchNormalization()(l_out2)
      l_out2 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(l_out2)
      l_out2 = BatchNormalization()(l_out2)

      l_up2 = concatenate([UpSampling2D(size=(2, 2))(l_out2), l_conv6], axis=3)

      l_out3 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(l_up2)
      l_out3 = BatchNormalization()(l_out3)
      l_out3 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(l_out3)
      l_out3 = BatchNormalization()(l_out3)

      l_up3 = concatenate([UpSampling2D(size=(2, 2))(l_out3), l_conv4], axis=3)

      l_out4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(l_up3)
      l_out4 = BatchNormalization()(l_out4)
      l_out4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(l_out4)
      l_out4 = BatchNormalization()(l_out4)

      #l_up5 = concatenate([UpSampling2D(size=(2, 2))(l_out4), l_conv6], axis=3)

      l_out5 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(l_out4)
      l_out5 = BatchNormalization()(l_out5)
      l_out5 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(l_out5)
      l_out5 = BatchNormalization()(l_out5)

      l_out = Conv2D(25,(1,1),activation = 'softmax',padding = 'same')(l_out5)

    
    
                
      d_conv1 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(merge)
      d_conv1 = BatchNormalization()(d_conv1)
      d_conv2 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(d_conv1)
      d_conv2 = BatchNormalization()(d_conv2)
      d_conv2 = UpSampling2D(size=(2, 2))(d_conv2)
      d_pool1 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv2)
    
      #d_up1 = concatenate([UpSampling2D(size=(2, 2))(d_out1), d_conv8], axis=3)

      d_conv3 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(d_pool1)
      d_conv3 = BatchNormalization()(d_conv1)
      d_conv4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(d_conv3)
      d_conv4 = BatchNormalization()(d_conv2)
      d_conv4 = UpSampling2D(size=(2, 2))(d_conv4)
      d_pool2 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv4)

      d_conv5 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(d_pool2)
      d_conv5 = BatchNormalization()(d_conv5)
      d_conv6 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(d_conv5)
      d_conv6 = BatchNormalization()(d_conv6)
      d_conv6 = UpSampling2D(size=(2, 2))(d_conv6)
      d_pool3 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv6)

      d_conv7 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(d_pool3)
      d_conv7 = BatchNormalization()(d_conv7)
      d_conv8 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(d_conv7)
      d_conv8 = BatchNormalization()(d_conv8)
      d_conv8 = UpSampling2D(size=(2, 2))(d_conv8)
      d_pool4 = MaxPooling2D(pool_size = (2,2),padding = 'same')(d_conv8)

      d_conv9 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(d_pool4)
      d_conv9 = BatchNormalization()(d_conv9)
      d_conv10 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(d_conv9)
      d_conv10 = UpSampling2D(size=(2, 2))(d_conv10)
      d_conv10 = BatchNormalization()(d_conv10)
        
      #d_out = Conv2D(3,(1,1),activation = 'linear',padding='same')(d_conv10)

      d_out1 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(d_conv10)
      d_out1 = BatchNormalization()(d_out1)
      d_out1 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(d_out1)
      d_out1 = BatchNormalization()(d_out1)

      d_up1 = UpSampling2D(size=(2, 2))(d_out1)

      d_out2 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(d_up1)
      d_out2 = BatchNormalization()(d_out2)
      d_out2 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(d_out2)
      d_out2 = BatchNormalization()(d_out2)

      #d_up2 = UpSampling2D(size=(2, 2))(d_out2)

      d_out3 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(d_out2)
      d_out3 = BatchNormalization()(d_out3)
      d_out3 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(d_out3)
      d_out3 = BatchNormalization()(d_out3)

      #d_up3 = UpSampling2D(size=(2, 2))(d_out3) 

      d_out4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(d_out3)
      d_out4 = BatchNormalization()(d_out4)
      d_out4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(d_out4)
      d_out4 = BatchNormalization()(d_out4)

      #l_up5 = concatenate([UpSampling2D(size=(2, 2))(l_out4), l_conv6], axis=3)

      d_out5 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(d_out4)
      d_out5 = BatchNormalization()(d_out5)
      d_out5 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(d_out5)
      d_out5 = BatchNormalization()(d_out5)

      d_out = Conv2D(3,(1,1),activation = 'linear',padding = 'same')(d_out5)




      r_out1 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(merge)
      r_out1 = BatchNormalization()(r_out1)
      r_out1 = Conv2D(n_filters * 16,(3,3),activation = 'relu',padding = 'same')(r_out1)
      r_out1 = BatchNormalization()(r_out1)

      r_up1 = concatenate([UpSampling2D(size=(2, 2))(r_out1), r_conv8], axis=3)

      r_out2 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(r_up1)
      r_out2 = BatchNormalization()(r_out2)
      r_out2 = Conv2D(n_filters * 8,(3,3),activation = 'relu',padding = 'same')(r_out2)
      r_out2 = BatchNormalization()(r_out2)

      r_up2 = concatenate([UpSampling2D(size=(2, 2))(r_out2), r_conv6], axis=3)

      r_out3 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(r_up2)
      r_out3 = BatchNormalization()(r_out3)
      r_out3 = Conv2D(n_filters * 4,(3,3),activation = 'relu',padding = 'same')(r_out3)
      r_out3 = BatchNormalization()(r_out3)

      r_up3 = concatenate([UpSampling2D(size=(2, 2))(r_out3), r_conv4], axis=3)

      r_out4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(r_up3)
      r_out4 = BatchNormalization()(r_out4)
      r_out4 = Conv2D(n_filters * 2,(3,3),activation = 'relu',padding = 'same')(r_out4)
      r_out4 = BatchNormalization()(r_out4)

      #r_up5 = concatenate([UpSampling2D(size=(2, 2))(r_out4), r_pool1], axis=3)

      r_out5 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(r_out4)
      r_out5 = BatchNormalization()(r_out5)
      r_out5 = Conv2D(n_filters * 1,(3,3),activation = 'relu',padding = 'same')(r_out5)
      r_out5 = BatchNormalization()(r_out5)

      r_out = Conv2D(25,(1,1),activation = 'softmax',padding = 'same')(r_out5)
      
      



      model = Model(inputs = [left_in,right_in],outputs = [l_out,r_out,d_out])

      return model

# %%
model = stereoDepthNet()

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_in (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# right_in (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 16) 448         left_in[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 224, 224, 16) 448         right_in[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 224, 224, 16) 64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 16) 2320        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 224, 224, 16) 64          batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 224, 224, 32) 4640        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 16) 64          batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 224, 224, 32) 128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 112, 112, 32) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 64) 9280        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 112, 112, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 64) 36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 112, 112, 64) 36928       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 112, 112, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 56, 56, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  147584      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 128)  147584      batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 256)  590080      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 256)  590080      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 512)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 16)   73744       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 16)   64          conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 16)   2320        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 16)   64          conv2d_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 16)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 56, 56, 16)   64          up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 16) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 56, 56, 16)   0           up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 64)   9280        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 56, 56, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 56, 56, 64)   36928       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 56, 56, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 112, 112, 64) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 56, 56, 64)   0           up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 56, 56, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 128)  147584      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 56, 56, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 112, 112, 128 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 56, 56, 128)  0           up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 28, 28, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 256)  295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 28, 28, 256)  1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 56, 56, 256)  1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 256)  590080      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  590080      batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 56, 56, 256)  590080      batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 256)  1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 112, 112, 256 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 56, 56, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 56, 56, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 112, 112, 256 1024        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d_9[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 112, 112, 256 590080      batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 112, 112, 256 1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 56, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 56, 56, 128)  512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 112, 112, 256 590080      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 128)  147584      batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 56, 56, 128)  147584      batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 112, 112, 256 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 56, 56, 128)  512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 56, 56, 128)  512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 224, 224, 256 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 112, 112, 128 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 112, 112, 128 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 224, 224, 128 295040      up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_10[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 224, 224, 128 512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 224, 224, 128 147584      batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 112, 112, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 112, 112, 64) 256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 224, 224, 128 512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 112, 112, 64) 36928       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 112, 112, 64) 36928       batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 224, 224, 64) 73792       batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 112, 112, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 112, 112, 64) 256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 224, 224, 64) 256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 64) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 224, 224, 64) 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 224, 224, 64) 36928       batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 80) 0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 224, 224, 96) 0           up_sampling2d_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 64) 256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 224, 224, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 18464       batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 224, 224, 32) 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 224, 224, 32) 128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 224, 224, 32) 9248        batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 224, 224, 32) 9248        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 224, 224, 32) 9248        batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 224, 224, 32) 128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 224, 224, 32) 128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 224, 224, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 224, 224, 16) 4624        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 224, 224, 16) 4624        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 224, 224, 16) 4624        batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 224, 224, 16) 64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 224, 224, 16) 64          conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 224, 224, 16) 64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 224, 224, 16) 2320        batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 224, 224, 16) 2320        batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 224, 224, 16) 2320        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 224, 224, 16) 64          conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 224, 224, 16) 64          conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 224, 224, 16) 64          conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 224, 224, 25) 425         batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 224, 224, 25) 425         batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 224, 224, 3)  51          batch_normalization_49[0][0]
# ==================================================================================================
# Total params: 10,442,613
# Trainable params: 10,430,965
# Non-trainable params: 11,648
# __________________________________________________________________________________________________

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='min', filepath='NoDepthRGB_DNetwork.h5', monitor='val_loss', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='min', monitor='val_loss', patience=10, verbose=1)
callbacks = [tb, mc, es]
smooth = 1
num_epochs = 100

# %%
model.load_weights('NoDepthRGB_DNetwork.h5')

# %%
# newModel = stereoNet()
model.compile(optimizer = 'adam',loss = ['categorical_crossentropy','categorical_crossentropy','MAE'],metrics = ['accuracy',dice_coef,dice_coef_loss])

# %%
# result = model.fit(StereoDepthGen(),
#           validation_data = StereoDepthGenVal(),
#           steps_per_epoch = 128,
#           validation_steps = 64, epochs = num_epochs, callbacks = callbacks,verbose = 1)

# %%
# model.save_weights('NoDepthRGB-DNetwork.h5')

# %%
testing_gen = StereoDepthGenTest()
[left_img,right_img],[mask,mask2,depth] = next(testing_gen)
pred_all= model.predict([left_img,right_img])
#np.shape(pred_all)
#print(np.shape(pred_all[0]))
# Out:
# Found 184 images belonging to 2 classes.
# Found 184 images belonging to 1 classes.
# Found 184 images belonging to 1 classes.
# Found 184 images belonging to 1 classes.
# Found 184 images belonging to 1 classes.

# %%
p = 1
for i in range(0,6):
    
    #print(batch_mask[i])
    fig = plt.figure(figsize=(20,8))
    
    ax1 = fig.add_subplot(1,5,1)
    ax1.imshow(right_img[i].astype(np.uint8))
    ax1.title.set_text('Actual frame')
    ax1.grid(False)
    
    
    ax2 = fig.add_subplot(1,5,2)
    ax2.set_title('Ground truth labels')
    ax2.imshow(onehot_to_rgb(np.asarray((mask2[i]))))
    ax2.grid(False)
    
    ax3 = fig.add_subplot(1,5,3)
    ax3.set_title('Predicted labels')
    ax3.imshow(onehot_to_rgb(pred_all[1][i]))
    ax3.grid(False)
    
    ax4 = fig.add_subplot(1,5,4)
    ax4.set_title('Ground Truth Depth')
    ax4.imshow(depth[i].astype(np.uint8))
    ax4.grid(False)
    
    ax5 = fig.add_subplot(1,5,5)
    ax5.set_title('Predicted depth')
    ax5.imshow(pred_all[2][i].astype(np.uint8))
    ax5.grid(False)
    plt.savefig('SegDepthRight' + str(p) + '.png')
    p =p + 1
    #plt.show()
    
#plt.saveplot('StereoSegResultsRight.png')
